# %% [markdown]
# # **Title:**
# #        **ITSM Improvement through Machine Learning: Enhancing Incident Management at ABC Tech.**

# %% [markdown]
# # **PROBLEM** **OF** **STATEMENT:**
#
# *   Predicting High Priority Tickets: To predict priority 1 & 2 tickets, so that they can take preventive measures or fix the problem before it surfaces.
#
# *   Forecast the incident volume in different fields , quarterly and annual. So that they can be better prepared with resources and technology planning.
#
# *    Auto tag the tickets with right priorities and right departments so that reassigning and related delay can be reduced.
#
# *    Predict RFC (Request for change) and possible failure / misconfiguration of ITSM assets.

# %% [markdown]
# # **Description:**
# ## **Business Case Description:**
#
# ABC Tech is an established mid-sized organization operating in the IT-enabled business sector for over a decade. They manage a significant volume of IT incidents and tickets, averaging between 22,000 to 25,000 per year. ABC Tech follows best practices in IT Service Management (ITSM), including incident management, problem management, change management, and configuration management processes. These ITIL practices have matured over time, reaching a high level of process maturity.
#
# Recently, ABC Tech conducted an audit that indicated that further improvement initiatives in their ITSM processes may not provide a sufficient return on investment (ROI). Despite their mature processes, customer feedback from recent surveys has revealed that incident management, in particular, is rated poorly, suggesting there is room for enhancement.
#
# In response to these challenges, ABC Tech's management has decided to explore the potential of machine learning (ML) to enhance their ITSM processes. After attending a Machine Learning conference focused on IT Service Management (ITSM), they identified four key areas where ML can contribute to improving ITSM processes within the organization:
#
# 1. **Predicting High Priority Tickets:** ABC Tech aims to develop an ML model that can predict high-priority tickets, specifically those categorized as priority 1 and 2. This prediction will allow them to take proactive measures to address issues or incidents before they escalate.
#
# 2. **Forecasting Incident Volume:** The organization plans to use ML to forecast the incident volume in different fields on a quarterly and annual basis. This predictive capability will help them better allocate resources and plan for the required technology upgrades.
#
# 3. **Auto-Tagging Tickets:** ABC Tech intends to implement a text classification ML model to automatically assign correct priorities and departments to incoming tickets. This automation will reduce reassignment and related delays in ticket handling.
#
# 4. **Predicting RFC and ITSM Asset Misconfigurations:** The organization aims to create predictive models for Request for Change (RFC) and detect potential failures or misconfigurations in ITSM assets. Identifying these issues in advance will help in preventing disruptions and improving overall ITSM asset management.
#
# The dataset that ABC Tech plans to use for these ML initiatives comprises a total of approximately 46,000 records spanning the years 2012, 2013, and 2014. The data is stored in a MySQL database with read-only access, and the relevant connection details are provided.
#
# Here's a summary of some key fields in the dataset:
#
# - CI_Name: Configuration Item Name
# - CI_Cat: Configuration Item Category
# - CI_Subcat: Configuration Item Subcategory
# - Incident_ID: Incident Identifier
# - Status: Incident Status (e.g., Closed)
# - Impact: Impact level
# - Urgency: Urgency level
# - Priority: Incident Priority
# - Category: Incident Category
# - KB_number: Knowledge Base Number
# - Alert_Status: Alert Status
# - No_of_Reassignments: Number of Reassignments
# - Open_Time: Incident Open Time
# - Reopen_Time: Incident Reopen Time
# - Resolved_Time: Incident Resolved Time
# - Close_Time: Incident Close Time
# - Handle_Time_hrs: Time taken to handle the incident (in hours)
# - Closure_Code: Code for incident closure
# - No_of_Related_Interactions: Number of Related Interactions
# - Related_Interaction: Identifier for Related Interaction
# - No_of_Related_Incidents: Number of Related Incidents
# - No_of_Related_Changes: Number of Related Changes
# - Related_Change: Identifier for Related Change

# %% [markdown]
# ## **Import Basic Libraries:**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **Load Data:**

# %%
data=pd.read_csv("/content/ITSM_data.csv")

# %%
#data=pd.set_option("display.max_columns",None)
#data=pd.set_option("display.expand_frame_repr",False)

# %%
data.head()
# Out:
#      CI_Name          CI_Cat              CI_Subcat        WBS Incident_ID  \
# 0  SUB000508  subapplication  Web Based Application  WBS000162   IM0000004
# 1  WBA000124     application  Web Based Application  WBS000088   IM0000005
# 2  DTA000024     application    Desktop Application  WBS000092   IM0000006
# 3  WBA000124     application  Web Based Application  WBS000088   IM0000011
# 4  WBA000124     application  Web Based Application  WBS000088   IM0000012
#
#    Status Impact Urgency  Priority  number_cnt  ...      Reopen_Time  \
# 0  Closed      4       4       4.0    0.601292  ...              NaN
# 1  Closed      3       3       3.0    0.415050  ...  2/12/2013 12:31
# 2  Closed     NS       3       NaN    0.517551  ...              NaN
# 3  Closed      4       4       4.0    0.642927  ...              NaN
# 4  Closed      4       4       4.0    0.345258  ...              NaN
#
#       Resolved_Time        Close_Time  Handle_Time_hrs  \
# 0   4/11/2013 13:50   4/11/2013 13:51   3,87,16,91,111
# 1   2/12/2013 12:36   2/12/2013 12:36   4,35,47,86,389
# 2  13-01-2014 15:12  13-01-2014 15:13   4,84,31,19,444
# 3  14-11-2013 09:31  14-11-2013 09:31   4,32,18,33,333
# 4   8/11/2013 13:55   8/11/2013 13:55   3,38,39,03,333
#
#                    Closure_Code No_of_Related_Interactions  \
# 0                         Other                        1.0
# 1                      Software                        1.0
# 2  No error - works as designed                        1.0
# 3                Operator error                        1.0
# 4                         Other                        1.0
#
#   Related_Interaction No_of_Related_Incidents No_of_Related_Changes  \
# 0           SD0000007                     2.0                   NaN
# 1           SD0000011                     1.0                   NaN
# 2           SD0000017                     NaN                   NaN
# 3           SD0000025                     NaN                   NaN
# 4           SD0000029                     NaN                   NaN
#
#   Related_Change
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 25 columns]

# %%
data.sample(20)
# Out:
#          CI_Name          CI_Cat                 CI_Subcat        WBS  \
# 31436  LAP000011        computer                    Laptop  WBS000091
# 26777  WBA000141     application     Web Based Application  WBS000068
# 38113  DTA000056     application       Desktop Application  WBS000091
# 42600  SBA000759     application  Server Based Application  WBS000296
# 9034   WBA000133     application     Web Based Application  WBS000073
# 39128  LAP000009        computer                    Laptop  WBS000091
# 26505  DTA000025     application       Desktop Application  WBS000110
# 37807  WBA000144     application     Web Based Application  WBS000318
# 28002  SBA000607     application  Server Based Application  WBS000263
# 33636  CBD000248        computer            Banking Device  WBS000146
# 18219  SUB000113  subapplication  Server Based Application  WBS000095
# 4192   SUB000535  subapplication     Web Based Application  WBS000066
# 33253  SUB000521  subapplication     Web Based Application  WBS000073
# 40175  SUB000508  subapplication     Web Based Application  WBS000162
# 24765  SBA000607     application  Server Based Application  WBS000263
# 15461  SBA000035     application  Server Based Application  WBS000007
# 36615  SBA000033     application  Server Based Application  WBS000086
# 33614  WBA000133     application     Web Based Application  WBS000073
# 17058  SUB000424  subapplication     Web Based Application  WBS000073
# 42359  SBA000609     application  Server Based Application  WBS000263
#
#       Incident_ID  Status Impact Urgency  Priority  number_cnt  ...  \
# 31436   IM0031725  Closed      5       5       5.0    0.294741  ...
# 26777   IM0027048  Closed      4       4       4.0    0.425201  ...
# 38113   IM0038431  Closed      3       3       3.0    0.652499  ...
# 42600   IM0042967  Closed      4       4       4.0    0.387019  ...
# 9034    IM0009199  Closed      4       4       4.0    0.846018  ...
# 39128   IM0039455  Closed      5       5       5.0    0.499765  ...
# 26505   IM0026774  Closed      4       4       4.0    0.573547  ...
# 37807   IM0038124  Closed      5       5       5.0    0.498607  ...
# 28002   IM0028275  Closed      5       5       5.0    0.024433  ...
# 33636   IM0033936  Closed      4       4       4.0    0.023187  ...
# 18219   IM0018443  Closed      5       5       5.0    0.395953  ...
# 4192    IM0004317  Closed      4       4       4.0    0.156612  ...
# 33253   IM0033551  Closed      4       4       4.0    0.372998  ...
# 40175   IM0040510  Closed      5       5       5.0    0.350681  ...
# 24765   IM0025025  Closed      4       4       4.0    0.493291  ...
# 15461   IM0015670  Closed      4       4       4.0    0.719867  ...
# 36615   IM0036927  Closed      4       4       4.0    0.433429  ...
# 33614   IM0033914  Closed      4       4       4.0    0.435902  ...
# 17058   IM0017274  Closed      5       5       5.0    0.569394  ...
# 42359   IM0042723  Closed      5       5       5.0    0.038665  ...
#
#             Reopen_Time     Resolved_Time        Close_Time  Handle_Time_hrs  \
# 31436               NaN  28-01-2014 16:58  28-01-2014 16:58             0,02
# 26777               NaN  20-01-2014 09:53  20-01-2014 09:53   6,96,08,33,333
# 38113               NaN  20-02-2014 11:41  20-02-2014 11:41      0,117777778
# 42600               NaN  13-03-2014 14:44  13-03-2014 14:44   1,44,62,22,222
# 9034                NaN   7/11/2013 10:46   7/11/2013 10:46   6,82,51,94,444
# 39128  26-02-2014 17:20   12/3/2014 17:02   12/3/2014 17:02           118,53
# 26505               NaN   10/1/2014 13:30   10/1/2014 13:30   1,46,36,94,444
# 37807               NaN  26-02-2014 15:39  26-02-2014 15:39   1,64,22,22,222
# 28002               NaN  17-01-2014 10:23  17-01-2014 10:23   2,12,23,05,556
# 33636               NaN   11/2/2014 15:48   11/2/2014 15:49   2,27,86,11,111
# 18219   2/12/2013 18:16    3/12/2013 7:48    3/12/2013 7:48      0,524166667
# 4192                NaN  14-10-2013 11:17  14-10-2013 11:17   1,97,50,27,778
# 33253               NaN    3/2/2014 16:44    3/2/2014 16:44             0,49
# 40175               NaN  21-03-2014 11:31  21-03-2014 11:31   1,55,32,27,778
# 24765               NaN    2/1/2014 16:33    2/1/2014 16:33   5,23,97,22,222
# 15461               NaN  21-11-2013 13:59  21-11-2013 13:59   1,52,61,11,111
# 36615               NaN  14-02-2014 14:05  14-02-2014 14:05   2,16,30,55,556
# 33614               NaN    4/2/2014 11:24    4/2/2014 11:24      0,114444444
# 17058               NaN  27-11-2013 17:14  27-11-2013 17:14   4,94,44,44,444
# 42359               NaN   11/3/2014 13:43   11/3/2014 13:43   1,83,88,88,889
#
#                        Closure_Code No_of_Related_Interactions  \
# 31436                      Hardware                        1.0
# 26777  No error - works as designed                        1.0
# 38113                      Software                        1.0
# 42600                       Inquiry                        1.0
# 9034                          Other                        1.0
# 39128                      Hardware                        4.0
# 26505                         Other                        1.0
# 37807                         Other                        1.0
# 28002                         Other                        1.0
# 33636                       Unknown                        1.0
# 18219                         Other                        2.0
# 4192                       Software                        1.0
# 33253                          Data                        1.0
# 40175                         Other                        1.0
# 24765                         Other                        1.0
# 15461  No error - works as designed                        1.0
# 36615                    User error                        1.0
# 33614                          Data                        1.0
# 17058                      Software                        1.0
# 42359                         Other                        1.0
#
#       Related_Interaction No_of_Related_Incidents No_of_Related_Changes  \
# 31436           SD0096124                     NaN                   NaN
# 26777           SD0081225                     NaN                   NaN
# 38113           SD0116992                     NaN                   1.0
# 42600           SD0132152                     NaN                   NaN
# 9034            SD0024728                     NaN                   NaN
# 39128         #MULTIVALUE                     NaN                   NaN
# 26505           SD0080140                     NaN                   NaN
# 37807           SD0116402                     1.0                   NaN
# 28002           SD0085104                     NaN                   NaN
# 33636           SD0102846                     NaN                   NaN
# 18219         #MULTIVALUE                     NaN                   NaN
# 4192            SD0010339                     NaN                   NaN
# 33253           SD0102183                     NaN                   NaN
# 40175           SD0123896                     NaN                   NaN
# 24765           SD0074615                     NaN                   NaN
# 15461           SD0044815                     NaN                   NaN
# 36615           SD0112379                     1.0                   NaN
# 33614           SD0102796                     NaN                   NaN
# 17058           SD0049564                     NaN                   NaN
# 42359           SD0131168                     NaN                   NaN
#
#       Related_Change
# 31436            NaN
# 26777            NaN
# 38113      C00014762
# 42600            NaN
# 9034             NaN
# 39128            NaN
# 26505            NaN
# 37807            NaN
# 28002            NaN
# 33636            NaN
# 18219            NaN
# 4192             NaN
# 33253            NaN
# 40175            NaN
# 24765            NaN
# 15461            NaN
# 36615            NaN
# 33614            NaN
# 17058            NaN
# 42359            NaN
#
# [20 rows x 25 columns]

# %%
data.drop(["CI_Name", "WBS", "Incident_ID", "KB_number", "Related_Interaction","Related_Change"], axis=1, inplace=True)

# %%
data.shape
# Out:
# (46606, 19)

# %% [markdown]
# # **Domain Analysis:**
# Certainly! Domain analysis is an essential step in any data science or machine learning project. It involves gaining a deep understanding of the domain-specific aspects of the problem you're trying to solve. In this case, we're analyzing the domain of IT Service Management (ITSM) within the context of ABC Tech's business case. Here's a domain analysis for ITSM:
#
# **1. IT Service Management (ITSM):**
#    - **Definition:** IT Service Management (ITSM) refers to a set of practices and processes used by organizations to design, deliver, manage, and improve IT services for their customers and end-users.
#    - **Importance:** ITSM ensures that IT services are aligned with business goals, reliable, and efficiently delivered, leading to enhanced customer satisfaction and business performance.
#
# **2. Incident Management:**
#    - **Definition:** Incident Management is a core ITSM process that involves identifying, categorizing, prioritizing, and resolving incidents to restore normal service operations as quickly as possible.
#    - **Challenges:** Common challenges in incident management include handling a high volume of incidents, determining incident priorities, minimizing response times, and reducing the impact on end-users.
#
# **3. Priority in ITSM:**
#    - **Definition:** Priority is a classification system used to categorize incidents based on their severity and impact on business operations. In ITIL (IT Infrastructure Library) framework, there are typically four priority levels: Priority 1 (Critical), Priority 2 (High), Priority 3 (Medium), and Priority 4 (Low).
#    - **Importance:** Prioritizing incidents helps organizations allocate resources effectively and respond to critical issues promptly.
#
# **4. ITIL Framework:**
#    - **Definition:** ITIL is a widely adopted framework for ITSM that provides best practices and guidelines for managing IT services, including incident management, problem management, change management, and configuration management.
#    - **Maturity Levels:** ITIL processes can mature over time, starting from ad-hoc practices and progressing to well-defined, controlled, and optimized processes. A mature ITIL framework leads to improved service quality and efficiency.
#
# **5. Machine Learning in ITSM:**
#    - **Application:** Machine learning can be applied to ITSM processes to predict incidents, automate ticket classification, forecast resource needs, and detect anomalies or misconfigurations in IT assets.
#    - **Benefits:** ML can enhance incident response, reduce manual workload, improve service quality, and proactively identify issues before they impact operations.
#
# **6. Data Considerations:**
#    - **Data Sources:** Data for ITSM projects typically come from various sources, including incident tracking systems, service logs, configuration databases, and customer feedback.
#    - **Data Quality:** Data quality is critical, as inaccurate or incomplete data can lead to incorrect predictions and decisions.
#    - **Privacy and Compliance:** ITSM data often contains sensitive information, so privacy and compliance with data protection regulations (e.g., GDPR) are crucial considerations.
#
# **7. Metrics and KPIs:**
#    - **Key Metrics:** Key Performance Indicators (KPIs) in ITSM include Mean Time to Resolve (MTTR), Incident Response Time, Incident Closure Rate, and Customer Satisfaction.
#    - **Monitoring:** Continuous monitoring of KPIs helps organizations assess the effectiveness of their ITSM processes and make improvements.
#
# **8. Stakeholders:**
#    - **Internal Stakeholders:** IT teams, IT managers, incident responders, change management teams.
#    - **External Stakeholders:** End-users, customers, auditors (for compliance).
#
# **9. Challenges:**
#    - **Scalability:** Handling a large volume of incidents efficiently can be challenging.
#    - **Data Integration:** Integrating data from disparate sources can be complex.
#    - **Change Management:** Implementing ML solutions may require organizational and cultural changes.

# %% [markdown]
# ## **Basic Checks:**

# %%
data.head()
# Out:
#            CI_Cat              CI_Subcat  Status Impact Urgency  Priority  \
# 0  subapplication  Web Based Application  Closed      4       4       4.0
# 1     application  Web Based Application  Closed      3       3       3.0
# 2     application    Desktop Application  Closed     NS       3       NaN
# 3     application  Web Based Application  Closed      4       4       4.0
# 4     application  Web Based Application  Closed      4       4       4.0
#
#    number_cnt                 Category Alert_Status  No_of_Reassignments  \
# 0    0.601292                 incident       closed                 26.0
# 1    0.415050                 incident       closed                 33.0
# 2    0.517551  request for information       closed                  3.0
# 3    0.642927                 incident       closed                 13.0
# 4    0.345258                 incident       closed                  2.0
#
#           Open_Time      Reopen_Time     Resolved_Time        Close_Time  \
# 0    5/2/2012 13:32              NaN   4/11/2013 13:50   4/11/2013 13:51
# 1   12/3/2012 15:44  2/12/2013 12:31   2/12/2013 12:36   2/12/2013 12:36
# 2  29-03-2012 12:36              NaN  13-01-2014 15:12  13-01-2014 15:13
# 3  17-07-2012 11:49              NaN  14-11-2013 09:31  14-11-2013 09:31
# 4   10/8/2012 11:01              NaN   8/11/2013 13:55   8/11/2013 13:55
#
#   Handle_Time_hrs                  Closure_Code  No_of_Related_Interactions  \
# 0  3,87,16,91,111                         Other                         1.0
# 1  4,35,47,86,389                      Software                         1.0
# 2  4,84,31,19,444  No error - works as designed                         1.0
# 3  4,32,18,33,333                Operator error                         1.0
# 4  3,38,39,03,333                         Other                         1.0
#
#    No_of_Related_Incidents  No_of_Related_Changes
# 0                      2.0                    NaN
# 1                      1.0                    NaN
# 2                      NaN                    NaN
# 3                      NaN                    NaN
# 4                      NaN                    NaN

# %%
data.tail()
# Out:
#             CI_Cat                 CI_Subcat  Status Impact Urgency  Priority  \
# 46601  application  Server Based Application  Closed      4       4       4.0
# 46602  application  Server Based Application  Closed      4       4       4.0
# 46603     computer                    Laptop  Closed      5       5       5.0
# 46604  application     Web Based Application  Closed      4       4       4.0
# 46605     hardware       DataCenterEquipment  Closed      3       3       3.0
#
#        number_cnt  Category Alert_Status  No_of_Reassignments  \
# 46601    0.231896  incident       closed                  0.0
# 46602    0.805153  incident       closed                  0.0
# 46603    0.917466  incident       closed                  0.0
# 46604    0.701278  incident       closed                  0.0
# 46605    0.902320  incident       closed                  0.0
#
#               Open_Time Reopen_Time     Resolved_Time        Close_Time  \
# 46601  31-03-2014 16:23         NaN  31-03-2014 16:29  31-03-2014 16:29
# 46602  31-03-2014 15:03         NaN  31-03-2014 15:29  31-03-2014 15:29
# 46603  31-03-2014 15:28         NaN  31-03-2014 15:32  31-03-2014 15:32
# 46604  31-03-2014 15:35         NaN  31-03-2014 15:42  31-03-2014 15:42
# 46605  31-03-2014 17:24         NaN  31-03-2014 22:47  31-03-2014 22:47
#
#       Handle_Time_hrs Closure_Code  No_of_Related_Interactions  \
# 46601           0,095        Other                         1.0
# 46602     0,428333333   User error                         1.0
# 46603     0,071666667     Hardware                         1.0
# 46604     0,116944444     Software                         1.0
# 46605     0,586388889     Hardware                         1.0
#
#        No_of_Related_Incidents  No_of_Related_Changes
# 46601                      NaN                    NaN
# 46602                      NaN                    NaN
# 46603                      NaN                    NaN
# 46604                      NaN                    NaN
# 46605                      NaN                    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46606 entries, 0 to 46605
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CI_Cat                      46495 non-null  object
#  1   CI_Subcat                   46495 non-null  object
#  2   Status                      46606 non-null  object
#  3   Impact                      46606 non-null  object
#  4   Urgency                     46606 non-null  object
#  5   Priority                    45226 non-null  float64
#  6   number_cnt                  46606 non-null  float64
#  7   Category                    46606 non-null  object
#  8   Alert_Status                46606 non-null  object
#  9   No_of_Reassignments         46605 non-null  float64
#  10  Open_Time                   46606 non-null  object
#  11  Reopen_Time                 2284 non-null   object
#  12  Resolved_Time               44826 non-null  object
#  13  Close_Time                  46606 non-null  object
#  14  Handle_Time_hrs             46605 non-null  object
#  15  Closure_Code                46146 non-null  object
#  16  No_of_Related_Interactions  46492 non-null  float64
#  17  No_of_Related_Incidents     1222 non-null   float64
#  18  No_of_Related_Changes       560 non-null    float64
# dtypes: float64(6), object(13)
# memory usage: 6.8+ MB

# %%
data.dtypes
# Out:
# CI_Cat                         object
# CI_Subcat                      object
# Status                         object
# Impact                         object
# Urgency                        object
# Priority                      float64
# number_cnt                    float64
# Category                       object
# Alert_Status                   object
# No_of_Reassignments           float64
# Open_Time                      object
# Reopen_Time                    object
# Resolved_Time                  object
# Close_Time                     object
# Handle_Time_hrs                object
# Closure_Code                   object
# No_of_Related_Interactions    float64
# No_of_Related_Incidents       float64
# No_of_Related_Changes         float64
# dtype: object

# %%
data.columns
# Out:
# Index(['CI_Cat', 'CI_Subcat', 'Status', 'Impact', 'Urgency', 'Priority',
#        'number_cnt', 'Category', 'Alert_Status', 'No_of_Reassignments',
#        'Open_Time', 'Reopen_Time', 'Resolved_Time', 'Close_Time',
#        'Handle_Time_hrs', 'Closure_Code', 'No_of_Related_Interactions',
#        'No_of_Related_Incidents', 'No_of_Related_Changes'],
#       dtype='object')

# %%
cat_data=data.select_dtypes(include=["O"]).columns
cat_data
# Out:
# Index(['CI_Cat', 'CI_Subcat', 'Status', 'Impact', 'Urgency', 'Category',
#        'Alert_Status', 'Open_Time', 'Reopen_Time', 'Resolved_Time',
#        'Close_Time', 'Handle_Time_hrs', 'Closure_Code'],
#       dtype='object')

# %%
for i in cat_data:
  print(i,data[i].unique())
  print(data[i].value_counts())
  print("----------------------------")
# Out:
# CI_Cat ['subapplication' 'application' 'computer' nan 'displaydevice' 'software'
#  'storage' 'database' 'hardware' 'officeelectronics' 'networkcomponents'
#  'applicationcomponent' 'Phone']
# application             32900
# subapplication           7782
# computer                 3643
# storage                   703
# hardware                  442
# software                  333
# database                  214
# displaydevice             212
# officeelectronics         152
# networkcomponents         107
# applicationcomponent        5
# Phone                       2
# Name: CI_Cat, dtype: int64
# ----------------------------
# CI_Subcat ['Web Based Application' 'Desktop Application' 'Server Based Application'
#  'SAP' 'Client Based Application' 'Citrix' 'Standard Application'
#  'Windows Server' 'Laptop' 'Linux Server' nan 'Monitor'
#  'Automation Software' 'SAN' 'Banking Device' 'Desktop' 'Database'
#  'Oracle Server' 'Keyboard' 'Printer' 'Exchange' 'System Software' 'VDI'
#  'Encryption' 'Omgeving' 'MigratieDummy' 'Scanner' 'Controller'
#  'DataCenterEquipment' 'KVM Switches' 'Switch' 'Database Software'
#  'Network Component' 'Unix Server' 'Lines' 'ESX Cluster' 'zOS Server'
#  'SharePoint Farm' 'NonStop Server' 'Application Server'
#  'Security Software' 'Thin Client' 'zOS Cluster' 'Router' 'VMWare'
#  'Net Device' 'Neoview Server' 'MQ Queue Manager' 'UPS' 'Number'
#  'Iptelephony' 'Windows Server in extern beheer' 'Modem' 'X86 Server'
#  'ESX Server' 'Virtual Tape Server' 'IPtelephony' 'NonStop Harddisk'
#  'Firewall' 'RAC Service' 'zOS Systeem' 'Instance' 'NonStop Storage'
#  'Protocol' 'Tape Library']
# Server Based Application    18811
# Web Based Application       15311
# Desktop Application          3876
# Laptop                       1921
# SAP                          1199
#                             ...
# VMWare                          1
# Application Server              1
# NonStop Storage                 1
# Protocol                        1
# Security Software               1
# Name: CI_Subcat, Length: 64, dtype: int64
# ----------------------------
# Status ['Closed' 'Work in progress']
# Closed              46597
# Work in progress        9
# Name: Status, dtype: int64
# ----------------------------
# Impact ['4' '3' 'NS' '5' '2' '1']
# 4     22556
# 5     16741
# 3      5234
# NS     1380
# 2       692
# 1         3
# Name: Impact, dtype: int64
# ----------------------------
# Urgency [4 3 5 2 1 '5' '3' '4' '2' '1' '5 - Very Low']
# 4               15526
# 5               12284
# 4                7062
# 5                4495
# 3                4419
# 3                2117
# 2                 538
# 2                 158
# 1                   5
# 1                   1
# 5 - Very Low        1
# Name: Urgency, dtype: int64
# ----------------------------
# Category ['incident' 'request for information' 'complaint' 'request for change']
# incident                   37748
# request for information     8846
# complaint                     11
# request for change             1
# Name: Category, dtype: int64
# ----------------------------
# Alert_Status ['closed']
# closed    46606
# Name: Alert_Status, dtype: int64
# ----------------------------
# Open_Time ['5/2/2012 13:32' '12/3/2012 15:44' '29-03-2012 12:36' ...
#  '31-03-2014 15:28' '31-03-2014 15:35' '31-03-2014 17:24']
# 24-03-2014 08:54    7
# 21-02-2014 15:01    6
# 24-01-2014 09:37    6
# 12/11/2013 11:04    6
# 21-01-2014 11:49    6
#                    ..
# 2/12/2013 13:28     1
# 2/12/2013 13:16     1
# 2/12/2013 13:11     1
# 2/12/2013 12:34     1
# 31-03-2014 17:24    1
# Name: Open_Time, Length: 34636, dtype: int64
# ----------------------------
# Reopen_Time [nan '2/12/2013 12:31' '28-01-2014 14:07' ... '31-03-2014 10:20'
#  '31-03-2014 10:55' '31-03-2014 16:21']
# 29-10-2013 15:03    2
# 17-01-2014 10:47    2
# 15-10-2013 09:46    2
# 17-02-2014 13:42    2
# 13-12-2013 16:20    2
#                    ..
# 15-11-2013 14:02    1
# 15-11-2013 08:38    1
# 14-11-2013 14:17    1
# 25-11-2013 16:14    1
# 31-03-2014 16:21    1
# Name: Reopen_Time, Length: 2244, dtype: int64
# ----------------------------
# Resolved_Time ['4/11/2013 13:50' '2/12/2013 12:36' '13-01-2014 15:12' ...
#  '31-03-2014 15:29' '31-03-2014 15:42' '31-03-2014 22:47']
# 10/10/2013 12:53    7
# 6/11/2013 5:12      6
# 16-12-2013 09:47    6
# 10/3/2014 9:41      6
# 31-03-2014 09:20    6
#                    ..
# 2/12/2013 9:20      1
# 2/12/2013 13:01     1
# 2/12/2013 8:37      1
# 10/12/2013 17:00    1
# 31-03-2014 22:47    1
# Name: Resolved_Time, Length: 33627, dtype: int64
# ----------------------------
# Close_Time ['4/11/2013 13:51' '2/12/2013 12:36' '13-01-2014 15:13' ...
#  '31-03-2014 16:29' '31-03-2014 15:32' '31-03-2014 22:47']
# 2/10/2013 15:20     21
# 3/12/2013 9:55      15
# 13-01-2014 15:09    13
# 21-02-2014 15:52    12
# 10/2/2014 12:29     11
#                     ..
# 3/12/2013 10:06      1
# 4/12/2013 10:55      1
# 3/12/2013 10:00      1
# 3/12/2013 13:35      1
# 31-03-2014 22:47     1
# Name: Close_Time, Length: 34528, dtype: int64
# ----------------------------
# Handle_Time_hrs ['3,87,16,91,111' '4,35,47,86,389' '4,84,31,19,444' ... '1,10,13,88,889'
#  '1,99,30,55,556' '0,428333333']
# 0                 236
# 0,034444444        23
# 0,018333333        22
# 0,016666667        19
# 0,021388889        19
#                  ...
# 4,28,85,27,778      1
# 3,92,91,66,667      1
# 4,96,68,05,556      1
# 1,07,30,27,778      1
# 0,428333333         1
# Name: Handle_Time_hrs, Length: 30638, dtype: int64
# ----------------------------
# Closure_Code ['Other' 'Software' 'No error - works as designed' 'Operator error'
#  'Unknown' 'Data' 'Referred' 'Hardware' 'Questions' 'User error' 'Inquiry'
#  'User manual not used' 'Kwaliteit van de output' nan 'Overig']
# Other                           16470
# Software                        13027
# User error                       3554
# No error - works as designed     3530
# Hardware                         2999
# Data                             2209
# Unknown                          1590
# Operator error                   1539
# User manual not used              765
# Inquiry                           162
# Referred                          158
# Questions                         132
# Kwaliteit van de output            10
# Overig                              1
# Name: Closure_Code, dtype: int64
# ----------------------------

# %%
num_data=data.select_dtypes(include=["float64","int64"]).columns
num_data
# Out:
# Index(['Priority', 'number_cnt', 'No_of_Reassignments',
#        'No_of_Related_Interactions', 'No_of_Related_Incidents',
#        'No_of_Related_Changes'],
#       dtype='object')

# %%
data.describe().T
# Out:
#                               count      mean       std       min       25%  \
# Priority                    45226.0  4.215805  0.705624  1.000000  4.000000
# number_cnt                  46606.0  0.499658  0.288634  0.000023  0.248213
# No_of_Reassignments         46605.0  1.131831  2.269774  0.000000  0.000000
# No_of_Related_Interactions  46492.0  1.149897  2.556338  1.000000  1.000000
# No_of_Related_Incidents      1222.0  1.669394  3.339687  1.000000  1.000000
# No_of_Related_Changes         560.0  1.058929  0.403596  1.000000  1.000000
#
#                                  50%       75%         max
# Priority                    4.000000  5.000000    5.000000
# number_cnt                  0.500269  0.749094    0.999997
# No_of_Reassignments         0.000000  2.000000   46.000000
# No_of_Related_Interactions  1.000000  1.000000  370.000000
# No_of_Related_Incidents     1.000000  1.000000   63.000000
# No_of_Related_Changes       1.000000  1.000000    9.000000

# %%
data.describe(include="object")
# Out:
#              CI_Cat                 CI_Subcat  Status Impact  Urgency  \
# count         46495                     46495   46606  46606    46606
# unique           12                        64       2      6       11
# top     application  Server Based Application  Closed      4        4
# freq          32900                     18811   46597  22556    15526
#
#         Category Alert_Status         Open_Time       Reopen_Time  \
# count      46606        46606             46606              2284
# unique         4            1             34636              2244
# top     incident       closed  24-03-2014 08:54  29-10-2013 15:03
# freq       37748        46606                 7                 2
#
#            Resolved_Time       Close_Time Handle_Time_hrs Closure_Code
# count              44826            46606           46605        46146
# unique             33627            34528           30638           14
# top     10/10/2013 12:53  2/10/2013 15:20               0        Other
# freq                   7               21             236        16470

# %% [markdown]
# ##Unique value will be 1 for constant column.Here, Alert_Status is the constant feature. so we drop the column.

# %%
data.sample()
# Out:
#          CI_Cat CI_Subcat  Status Impact Urgency  Priority  number_cnt  \
# 12575  computer    Laptop  Closed      5       5       5.0    0.015107
#
#        Category Alert_Status  No_of_Reassignments        Open_Time  \
# 12575  incident       closed                  0.0  12/11/2013 9:30
#
#       Reopen_Time     Resolved_Time        Close_Time Handle_Time_hrs  \
# 12575         NaN  13-11-2013 15:42  13-11-2013 15:42  1,66,91,94,444
#
#       Closure_Code  No_of_Related_Interactions  No_of_Related_Incidents  \
# 12575     Hardware                         1.0                      NaN
#
#        No_of_Related_Changes
# 12575                    NaN

# %%
data.drop(["Alert_Status"],axis=1,inplace=True)

# %% [markdown]
# ##**Basic Checks Report:**
# ###**Overview:**
# When working with IT Service Management (ITSM) data or any dataset, it's essential to perform basic data checks to ensure the quality and integrity of the data. These basic checks help identify issues early on and ensure that your analysis or project is based on reliable data.
#
# **Data Shape**: We Check the dimensions of the dataset, i.e., the number of rows and columns, using data.shape. Data Contains 46606 Rows and 25 columns.
# **Data Types:** We Verified that the data types of each column are as expected usingdata.dtypes.Priority,number_cnt,No_of_Related_Interactions,No_of_Related_Incidents,No_of_Related_Changes,No_of_Reassignments are in float64 and remaining columns are in object.
#
# **Descriptive Statistics:** We Used data.describe().T to get summary statistics (mean, min, max, etc.) for numerical columns.
# Use data.describe(include='O').T for a summary of categorical columns.
#
# **Unique Values:** Checked the number of unique values in categorical columns using data['column'].unique(). here, One constant columns are there. so we dropped that column.
#
# **Value Counts:** Examined the distribution of categorical values using df['column'].value_counts().
#
# The goal is to ensure that our data is clean, complete, and suitable for analysis or further processing.

# %% [markdown]
# #**Data Preprocessing**

# %%
data.columns
# Out:
# Index(['CI_Cat', 'CI_Subcat', 'Status', 'Impact', 'Urgency', 'Priority',
#        'number_cnt', 'Category', 'No_of_Reassignments', 'Open_Time',
#        'Reopen_Time', 'Resolved_Time', 'Close_Time', 'Handle_Time_hrs',
#        'Closure_Code', 'No_of_Related_Interactions', 'No_of_Related_Incidents',
#        'No_of_Related_Changes'],
#       dtype='object')

# %%
data.dtypes
# Out:
# CI_Cat                         object
# CI_Subcat                      object
# Status                         object
# Impact                         object
# Urgency                        object
# Priority                      float64
# number_cnt                    float64
# Category                       object
# No_of_Reassignments           float64
# Open_Time                      object
# Reopen_Time                    object
# Resolved_Time                  object
# Close_Time                     object
# Handle_Time_hrs                object
# Closure_Code                   object
# No_of_Related_Interactions    float64
# No_of_Related_Incidents       float64
# No_of_Related_Changes         float64
# dtype: object

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# CI_Cat                          111
# CI_Subcat                       111
# Status                            0
# Impact                            0
# Urgency                           0
# Priority                       1380
# number_cnt                        0
# Category                          0
# No_of_Reassignments               1
# Open_Time                         0
# Reopen_Time                   44322
# Resolved_Time                  1780
# Close_Time                        0
# Handle_Time_hrs                   1
# Closure_Code                    460
# No_of_Related_Interactions      114
# No_of_Related_Incidents       45384
# No_of_Related_Changes         46046
# dtype: int64

# %% [markdown]
# ## **Replacing Null Values**

# %% [markdown]
# ### **Replacing Null Values for CI_Cat**

# %%
data[data["CI_Cat"].isnull()]["CI_Cat"]
# Out:
# 316      NaN
# 538      NaN
# 593      NaN
# 670      NaN
# 1128     NaN
#         ...
# 34462    NaN
# 34868    NaN
# 36150    NaN
# 38262    NaN
# 38429    NaN
# Name: CI_Cat, Length: 111, dtype: object

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=data, x=data['CI_Cat'], kde=True)
# Out:
# <Axes: xlabel='CI_Cat', ylabel='Count'>

# %% [markdown]
# * The majority of the data is between 0 and 600.
# * There are a few outliers at the high end.
# * The median is slightly higher than the mode, which suggests that the data is somewhat skewed to the right.

# %%
data["CI_Cat"].mode()
# Out:
# 0    application
# Name: CI_Cat, dtype: object

# %%
data.CI_Cat.unique()
data.CI_Cat.value_counts()
# Out:
# application             32900
# subapplication           7782
# computer                 3643
# storage                   703
# hardware                  442
# software                  333
# database                  214
# displaydevice             212
# officeelectronics         152
# networkcomponents         107
# applicationcomponent        5
# Phone                       2
# Name: CI_Cat, dtype: int64

# %%
data.loc[data["CI_Cat"].isnull()==True,"CI_Cat"]="application"

# %%
data.isnull().sum()
# Out:
# CI_Cat                            0
# CI_Subcat                       111
# Status                            0
# Impact                            0
# Urgency                           0
# Priority                       1380
# number_cnt                        0
# Category                          0
# No_of_Reassignments               1
# Open_Time                         0
# Reopen_Time                   44322
# Resolved_Time                  1780
# Close_Time                        0
# Handle_Time_hrs                   1
# Closure_Code                    460
# No_of_Related_Interactions      114
# No_of_Related_Incidents       45384
# No_of_Related_Changes         46046
# dtype: int64

# %% [markdown]
# ### **Replacing Null Values for CI_Subcat**

# %%
data[data["CI_Subcat"].isnull()]["CI_Subcat"]
# Out:
# 316      NaN
# 538      NaN
# 593      NaN
# 670      NaN
# 1128     NaN
#         ...
# 34462    NaN
# 34868    NaN
# 36150    NaN
# 38262    NaN
# 38429    NaN
# Name: CI_Subcat, Length: 111, dtype: object

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=data, x=data['CI_Subcat'], kde=True)
# Out:
# <Axes: xlabel='CI_Subcat', ylabel='Count'>

# %% [markdown]
# * The distribution of the CI_Subcat column is skewed to the right.
# * There is a small number of outliers at the high end, representing CI_Subcat values of In Progress and Not Started.

# %%
data["CI_Subcat"].mode()
# Out:
# 0    Server Based Application
# Name: CI_Subcat, dtype: object

# %%
data.CI_Subcat.unique()
data.CI_Subcat.value_counts()
# Out:
# Server Based Application    18811
# Web Based Application       15311
# Desktop Application          3876
# Laptop                       1921
# SAP                          1199
#                             ...
# VMWare                          1
# Application Server              1
# NonStop Storage                 1
# Protocol                        1
# Security Software               1
# Name: CI_Subcat, Length: 64, dtype: int64

# %%
data.loc[data["CI_Subcat"].isnull()==True,"CI_Subcat"]="Server Based Application"

# %%
data.isnull().sum()
# Out:
# CI_Cat                            0
# CI_Subcat                         0
# Status                            0
# Impact                            0
# Urgency                           0
# Priority                       1380
# number_cnt                        0
# Category                          0
# No_of_Reassignments               1
# Open_Time                         0
# Reopen_Time                   44322
# Resolved_Time                  1780
# Close_Time                        0
# Handle_Time_hrs                   1
# Closure_Code                    460
# No_of_Related_Interactions      114
# No_of_Related_Incidents       45384
# No_of_Related_Changes         46046
# dtype: int64

# %% [markdown]
# ### **Replacing Null Values for Priority**

# %%
data[data["Priority"].isnull()]["Priority"]
# Out:
# 2       NaN
# 8       NaN
# 103     NaN
# 147     NaN
# 152     NaN
#          ..
# 46424   NaN
# 46446   NaN
# 46484   NaN
# 46553   NaN
# 46590   NaN
# Name: Priority, Length: 1380, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=data, x=data['Priority'], kde=True)
# Out:
# <Axes: xlabel='Priority', ylabel='Count'>

# %% [markdown]
# * The distribution of the data is skewed to the right, with most values between 20 and 50.
# * There are a few outliers at the high end, with values above 100.

# %%
data["Priority"].median()
# Out:
# 4.0

# %%
data["Priority"].mode()
# Out:
# 0    4.0
# Name: Priority, dtype: float64

# %%
data.loc[data["Priority"].isnull()==True,"Priority"]=4.0

# %%
data.isnull().sum()
# Out:
# CI_Cat                            0
# CI_Subcat                         0
# Status                            0
# Impact                            0
# Urgency                           0
# Priority                          0
# number_cnt                        0
# Category                          0
# No_of_Reassignments               1
# Open_Time                         0
# Reopen_Time                   44322
# Resolved_Time                  1780
# Close_Time                        0
# Handle_Time_hrs                   1
# Closure_Code                    460
# No_of_Related_Interactions      114
# No_of_Related_Incidents       45384
# No_of_Related_Changes         46046
# dtype: int64

# %%
data.sample(10)
# Out:
#                CI_Cat                 CI_Subcat  Status Impact Urgency  \
# 34639     application       Desktop Application  Closed      4       4
# 45199     application  Server Based Application  Closed      5       5
# 44944     application       Desktop Application  Closed      4       4
# 42149     application  Server Based Application  Closed      3       3
# 1257      application  Server Based Application  Closed      4       4
# 20407  subapplication     Web Based Application  Closed      4       4
# 23179        computer                    Laptop  Closed      5       5
# 42522         storage                Controller  Closed      3       3
# 37695     application       Desktop Application  Closed     NS       3
# 24521         storage                       SAN  Closed      4       4
#
#        Priority  number_cnt  Category  No_of_Reassignments         Open_Time  \
# 34639       4.0    0.120459  incident                  0.0    6/2/2014 17:13
# 45199       5.0    0.727356  incident                  0.0  24-03-2014 13:47
# 44944       4.0    0.361151  incident                  0.0  24-03-2014 09:00
# 42149       3.0    0.573160  incident                  1.0   10/3/2014 16:24
# 1257        4.0    0.658729  incident                  0.0   1/10/2013 10:05
# 20407       4.0    0.168460  incident                  0.0  10/12/2013 15:04
# 23179       5.0    0.396450  incident                  0.0  23-12-2013 09:10
# 42522       3.0    0.346834  incident                  0.0   11/3/2014 17:11
# 37695       4.0    0.528557  incident                  0.0  19-02-2014 08:18
# 24521       4.0    0.560909  incident                  0.0  31-12-2013 11:57
#
#       Reopen_Time     Resolved_Time        Close_Time Handle_Time_hrs  \
# 34639         NaN    6/2/2014 17:47    6/2/2014 17:47           0,565
# 45199         NaN  25-03-2014 12:42  25-03-2014 12:42  9,40,19,44,444
# 44944         NaN  24-03-2014 09:48  24-03-2014 09:48     0,801944444
# 42149         NaN   10/3/2014 17:07   10/3/2014 17:07     0,713611111
# 1257          NaN    2/10/2013 8:00    2/10/2013 8:01  8,44,11,11,111
# 20407         NaN   11/12/2013 7:57   11/12/2013 7:57  3,37,80,55,556
# 23179         NaN  31-12-2013 09:14  31-12-2013 09:15        2,28,775
# 42522         NaN   12/3/2014 16:21   12/3/2014 16:22  9,67,27,77,778
# 37695         NaN  19-02-2014 08:30  19-02-2014 08:30     0,206111111
# 24521         NaN     2/1/2014 9:22     2/1/2014 9:22  7,91,33,33,333
#
#       Closure_Code  No_of_Related_Interactions  No_of_Related_Incidents  \
# 34639        Other                         1.0                      NaN
# 45199         Data                         1.0                      NaN
# 44944     Software                         1.0                      1.0
# 42149   User error                         1.0                      NaN
# 1257       Unknown                         1.0                      NaN
# 20407        Other                         1.0                      NaN
# 23179     Hardware                         1.0                      NaN
# 42522     Hardware                         1.0                      NaN
# 37695     Software                         1.0                      NaN
# 24521        Other                         1.0                      NaN
#
#        No_of_Related_Changes
# 34639                    NaN
# 45199                    NaN
# 44944                    NaN
# 42149                    NaN
# 1257                     NaN
# 20407                    NaN
# 23179                    NaN
# 42522                    NaN
# 37695                    1.0
# 24521                    NaN

# %% [markdown]
# ### **Remove the row with the null value for No_of_Reassignments**

# %%
# Remove the row with the null value in the 'No_of_Reassignments' column
data = data.dropna(subset=['No_of_Reassignments'])

# %%
data.isnull().sum()
# Out:
# CI_Cat                            0
# CI_Subcat                         0
# Status                            0
# Impact                            0
# Urgency                           0
# Priority                          0
# number_cnt                        0
# Category                          0
# No_of_Reassignments               0
# Open_Time                         0
# Reopen_Time                   44321
# Resolved_Time                  1780
# Close_Time                        0
# Handle_Time_hrs                   0
# Closure_Code                    460
# No_of_Related_Interactions      114
# No_of_Related_Incidents       45383
# No_of_Related_Changes         46045
# dtype: int64

# %% [markdown]
# ### **Replacing Null Values for Closure_Code**

# %%
data[data["Closure_Code"].isnull()]["Closure_Code"]
# Out:
# 9275     NaN
# 9488     NaN
# 9698     NaN
# 9989     NaN
# 10045    NaN
#         ...
# 46077    NaN
# 46247    NaN
# 46291    NaN
# 46357    NaN
# 46413    NaN
# Name: Closure_Code, Length: 460, dtype: object

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=data, x=data['Closure_Code'], kde=True)
# Out:
# <Axes: xlabel='Closure_Code', ylabel='Count'>

# %%
data["Closure_Code"].mode()
# Out:
# 0    Other
# Name: Closure_Code, dtype: object

# %%
data.Closure_Code.unique()
data.Closure_Code.value_counts()
# Out:
# Other                           16470
# Software                        13026
# User error                       3554
# No error - works as designed     3530
# Hardware                         2999
# Data                             2209
# Unknown                          1590
# Operator error                   1539
# User manual not used              765
# Inquiry                           162
# Referred                          158
# Questions                         132
# Kwaliteit van de output            10
# Overig                              1
# Name: Closure_Code, dtype: int64

# %%
data.loc[data["Closure_Code"].isnull()==True,"Closure_Code"]="other"

# %%
data.isnull().sum()
# Out:
# CI_Cat                            0
# CI_Subcat                         0
# Status                            0
# Impact                            0
# Urgency                           0
# Priority                          0
# number_cnt                        0
# Category                          0
# No_of_Reassignments               0
# Open_Time                         0
# Reopen_Time                   44321
# Resolved_Time                  1780
# Close_Time                        0
# Handle_Time_hrs                   0
# Closure_Code                      0
# No_of_Related_Interactions      114
# No_of_Related_Incidents       45383
# No_of_Related_Changes         46045
# dtype: int64

# %% [markdown]
# ## **Replacing Null Values for No_of_Related_Interactions**

# %%
data[data["No_of_Related_Interactions"].isnull()]["No_of_Related_Interactions"]
# Out:
# 300     NaN
# 1085    NaN
# 2483    NaN
# 3035    NaN
# 3299    NaN
#          ..
# 46468   NaN
# 46469   NaN
# 46470   NaN
# 46472   NaN
# 46473   NaN
# Name: No_of_Related_Interactions, Length: 114, dtype: float64

# %%
plt.figure(figsize=(4,4))
sns.histplot(data=data, x=data['No_of_Related_Interactions'], kde=True)
# Out:
# <Axes: xlabel='No_of_Related_Interactions', ylabel='Count'>

# %%
data["No_of_Related_Interactions"].median()
# Out:
# 1.0

# %%
data["No_of_Related_Interactions"].mode()
# Out:
# 0    1.0
# Name: No_of_Related_Interactions, dtype: float64

# %%
data.loc[data["No_of_Related_Interactions"].isnull()==True,"No_of_Related_Interactions"]=1.0

# %%
data.isnull().sum()
# Out:
# CI_Cat                            0
# CI_Subcat                         0
# Status                            0
# Impact                            0
# Urgency                           0
# Priority                          0
# number_cnt                        0
# Category                          0
# No_of_Reassignments               0
# Open_Time                         0
# Reopen_Time                   44321
# Resolved_Time                  1780
# Close_Time                        0
# Handle_Time_hrs                   0
# Closure_Code                      0
# No_of_Related_Interactions        0
# No_of_Related_Incidents       45383
# No_of_Related_Changes         46045
# dtype: int64

# %% [markdown]
# # **Check for Outliers**

# %%
num_data=data.select_dtypes(include=["int64","float64"]).columns

# %%
num_data
# Out:
# Index(['Priority', 'number_cnt', 'No_of_Reassignments',
#        'No_of_Related_Interactions', 'No_of_Related_Incidents',
#        'No_of_Related_Changes'],
#       dtype='object')

# %%
cat_data
# Out:
# Index(['CI_Cat', 'CI_Subcat', 'Status', 'Impact', 'Urgency', 'Category',
#        'Alert_Status', 'Open_Time', 'Reopen_Time', 'Resolved_Time',
#        'Close_Time', 'Handle_Time_hrs', 'Closure_Code'],
#       dtype='object')

# %% [markdown]
# ## **Box Plot for number_cnt**

# %%
# Create a box plot for the 'number_cnt' column
plt.figure(figsize=(8, 6))
sns.boxplot(x=data['number_cnt'])
plt.title('Box Plot of number_cnt')
plt.ylabel('number_cnt')
plt.show()

# %% [markdown]
# ## **Box Plot for No_of_Reassignments**

# %%
# Create a box plot for the 'number_cnt' column
plt.figure(figsize=(8, 6))
sns.boxplot(x=data['No_of_Reassignments'])
plt.title('Box Plot of No_of_Reassignments')
plt.ylabel('No_of_Reassignments')
plt.show()

# %% [markdown]
# ## **Outliers Handle for No_of_Reassignments**

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=data,x='No_of_Reassignments',kde=True)
# Out:
# <Axes: xlabel='No_of_Reassignments', ylabel='Count'>

# %% [markdown]
# ### **Insights**
# * Most tickets (0 reassignments) are resolved without being reassigned.
# * Reassignments decrease exponentially.
# * There is a small peak at 3 reassignments.
# * The graph is skewed to the right, meaning more tickets have a few reassignments than many reassignments.

# %%
Q1=data["No_of_Reassignments"].quantile(0.25)
print("lower_quartile",Q1)
Q3=data["No_of_Reassignments"].quantile(0.75)
print("upper_quartile",Q3)
# Out:
# lower_quartile 0.0
# upper_quartile 2.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 2.0

# %%
lower_limit=Q1-1.5*IQR
print("lower_limit is",lower_limit)
upper_limit=Q3+1.5*IQR
print("upper_limit is",upper_limit)
# Out:
# lower_limit is -3.0
# upper_limit is 5.0

# %%
data.loc[data["No_of_Reassignments"]>upper_limit]
# Out:
#                CI_Cat                 CI_Subcat  Status Impact Urgency  \
# 0      subapplication     Web Based Application  Closed      4       4
# 1         application     Web Based Application  Closed      3       3
# 3         application     Web Based Application  Closed      4       4
# 10        application     Web Based Application  Closed      4       4
# 11        application     Web Based Application  Closed      4       4
# ...               ...                       ...     ...    ...     ...
# 44961     application  Server Based Application  Closed      3       3
# 45040     application  Server Based Application  Closed      5       5
# 45196     application  Server Based Application  Closed      4       4
# 45273     application       Desktop Application  Closed      4       4
# 46063     application  Server Based Application  Closed      5       5
#
#        Priority  number_cnt                 Category  No_of_Reassignments  \
# 0           4.0    0.601292                 incident                 26.0
# 1           3.0    0.415050                 incident                 33.0
# 3           4.0    0.642927                 incident                 13.0
# 10          4.0    0.439909                 incident                  6.0
# 11          4.0    0.291928                 incident                  8.0
# ...         ...         ...                      ...                  ...
# 44961       3.0    0.267787                 incident                 10.0
# 45040       5.0    0.680022                 incident                  6.0
# 45196       4.0    0.449103                 incident                  7.0
# 45273       4.0    0.166302                 incident                  8.0
# 46063       5.0    0.117214  request for information                  6.0
#
#               Open_Time       Reopen_Time     Resolved_Time        Close_Time  \
# 0        5/2/2012 13:32               NaN   4/11/2013 13:50   4/11/2013 13:51
# 1       12/3/2012 15:44   2/12/2013 12:31   2/12/2013 12:36   2/12/2013 12:36
# 3      17-07-2012 11:49               NaN  14-11-2013 09:31  14-11-2013 09:31
# 10     21-09-2012 12:56               NaN   8/11/2013 14:23   8/11/2013 14:23
# 11      1/10/2012 10:49               NaN   8/11/2013 14:18   8/11/2013 14:22
# ...                 ...               ...               ...               ...
# 44961  21-03-2014 15:57  31-03-2014 11:45  31-03-2014 17:28  31-03-2014 17:28
# 45040  24-03-2014 09:57               NaN  25-03-2014 14:30  25-03-2014 14:30
# 45196  24-03-2014 13:33               NaN  26-03-2014 08:43  26-03-2014 08:43
# 45273  25-03-2014 08:40               NaN  31-03-2014 12:48  31-03-2014 12:48
# 46063  27-03-2014 11:47  27-03-2014 15:13  31-03-2014 08:04  31-03-2014 08:04
#
#       Handle_Time_hrs    Closure_Code  No_of_Related_Interactions  \
# 0      3,87,16,91,111           Other                         1.0
# 1      4,35,47,86,389        Software                         1.0
# 3      4,32,18,33,333  Operator error                         1.0
# 10     3,06,74,49,167        Software                         1.0
# 11     1,32,26,19,167        Software                         1.0
# ...               ...             ...                         ...
# 44961  5,81,92,22,222           Other                         2.0
# 45040  1,50,36,66,667        Software                         1.0
# 45196  1,61,62,77,778           Other                         1.0
# 45273  3,17,67,22,222        Software                         1.0
# 46063  1,72,11,11,111           Other                         2.0
#
#        No_of_Related_Incidents  No_of_Related_Changes
# 0                          2.0                    NaN
# 1                          1.0                    NaN
# 3                          NaN                    NaN
# 10                         NaN                    1.0
# 11                         NaN                    NaN
# ...                        ...                    ...
# 44961                      NaN                    NaN
# 45040                      NaN                    NaN
# 45196                      NaN                    NaN
# 45273                      NaN                    NaN
# 46063                      NaN                    NaN
#
# [1973 rows x 18 columns]

# %%
len(data.loc[data["No_of_Reassignments"]>upper_limit])/len(data)
# Out:
# 0.042334513464220576

# %%
data.loc[data["No_of_Reassignments"]>upper_limit,"No_of_Reassignments"]=data["No_of_Reassignments"].median()

# %%
sns.boxplot(x=data.No_of_Reassignments)
# Out:
# <Axes: xlabel='No_of_Reassignments'>

# %% [markdown]
# ## **Box Plot for No_of_Related_Interactions**

# %%
# Create a box plot for the 'No_of_Related_Interactions' column
plt.figure(figsize=(8, 6))
sns.boxplot(x=data['No_of_Related_Interactions'])
plt.title('Box Plot of No_of_Related_Interactions')
plt.ylabel('No_of_Related_Interactions')
plt.show()

# %% [markdown]
# ## **Outliers Handle for No_of_Related_Interactions**

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=data,x='No_of_Related_Interactions',kde=True)
# Out:
# <Axes: xlabel='No_of_Related_Interactions', ylabel='Count'>

# %% [markdown]
# ### **Insights**
# * Most tickets (0 reassignments) are resolved without being reassigned.
# * Reassignments decrease exponentially.
# * There is a small peak at 3 reassignments.
# * The graph is skewed to the right, meaning more tickets have a few reassignments than many reassignments.

# %%
Q1 = data["No_of_Related_Interactions"].quantile(0.25)
print("lower_quantile",Q1)
Q3 = data["No_of_Related_Interactions"].quantile(0.75)
print("upper_quantile",Q3)
# Out:
# lower_quantile 1.0
# upper_quantile 1.0

# %%
IQR=Q3 - Q1
IQR
# Out:
# 0.0

# %%
lower_limit = Q1-1.5*IQR
print("lower_limit is",lower_limit)
upper_limit = Q3+1.5*IQR
print("upper_limit is",upper_limit)
# Out:
# lower_limit is 1.0
# upper_limit is 1.0

# %%
data.loc[data["No_of_Related_Interactions"]>upper_limit]
# Out:
#             CI_Cat                 CI_Subcat  Status Impact Urgency  Priority  \
# 12     application     Web Based Application  Closed      4       4       4.0
# 18     application       Desktop Application  Closed      3       3       3.0
# 19     application     Web Based Application  Closed      5       5       5.0
# 27     application  Server Based Application  Closed      5       5       5.0
# 29     application  Server Based Application  Closed      5       5       5.0
# ...            ...                       ...     ...    ...     ...       ...
# 46455  application  Server Based Application  Closed      4       4       4.0
# 46458  application  Server Based Application  Closed      5       5       5.0
# 46460  application  Server Based Application  Closed      5       3       4.0
# 46471  application  Server Based Application  Closed      5       5       5.0
# 46598  application     Web Based Application  Closed      5       5       5.0
#
#        number_cnt                 Category  No_of_Reassignments  \
# 12       0.776486                 incident                  5.0
# 18       0.860255                 incident                  0.0
# 19       0.663615                 incident                  5.0
# 27       0.748361  request for information                  0.0
# 29       0.853722  request for information                  2.0
# ...           ...                      ...                  ...
# 46455    0.175887                 incident                  1.0
# 46458    0.969598                 incident                  0.0
# 46460    0.628989                 incident                  0.0
# 46471    0.280788                 incident                  0.0
# 46598    0.115338                 incident                  3.0
#
#               Open_Time       Reopen_Time     Resolved_Time        Close_Time  \
# 12      2/10/2012 12:12  28-01-2014 14:07     4/2/2014 9:38     4/2/2014 9:38
# 18      7/12/2012 14:34               NaN  30-11-2013 10:39  30-11-2013 10:39
# 19     10/12/2012 14:44   11/2/2014 14:50  28-03-2014 14:20  28-03-2014 14:20
# 27       6/2/2013 14:07  17-10-2013 12:22  17-10-2013 14:00  17-10-2013 14:00
# 29     18-02-2013 11:59   4/12/2013 13:58               NaN   4/12/2013 14:00
# ...                 ...               ...               ...               ...
# 46455  31-03-2014 08:41  31-03-2014 10:55  31-03-2014 11:56  31-03-2014 11:56
# 46458  31-03-2014 08:58               NaN  31-03-2014 09:30  31-03-2014 09:30
# 46460  31-03-2014 09:05               NaN  31-03-2014 09:28  31-03-2014 09:29
# 46471  31-03-2014 08:17               NaN  31-03-2014 09:19  31-03-2014 09:19
# 46598  31-03-2014 15:55  31-03-2014 16:21  31-03-2014 17:20  31-03-2014 17:20
#
#       Handle_Time_hrs                  Closure_Code  \
# 12     1,13,24,28,333                      Software
# 18     2,62,67,33,889                         Other
# 19     9,31,78,08,333                         Other
# 27     3,88,55,55,556  No error - works as designed
# 29     2,77,45,55,556                         Other
# ...               ...                           ...
# 46455  1,55,94,44,444                         Other
# 46458     0,084722222                      Software
# 46460     0,407777778                      Software
# 46471            1,03                      Software
# 46598  1,38,13,88,889                      Software
#
#        No_of_Related_Interactions  No_of_Related_Incidents  \
# 12                            2.0                      NaN
# 18                            2.0                      NaN
# 19                            2.0                      NaN
# 27                            2.0                      NaN
# 29                            2.0                      NaN
# ...                           ...                      ...
# 46455                         2.0                      NaN
# 46458                         2.0                      NaN
# 46460                         2.0                      NaN
# 46471                         2.0                      NaN
# 46598                         2.0                      NaN
#
#        No_of_Related_Changes
# 12                       NaN
# 18                       NaN
# 19                       NaN
# 27                       NaN
# 29                       NaN
# ...                      ...
# 46455                    NaN
# 46458                    NaN
# 46460                    NaN
# 46471                    NaN
# 46598                    NaN
#
# [3434 rows x 18 columns]

# %%
data.loc[data["No_of_Related_Interactions"]<lower_limit]
# Out:
# Empty DataFrame
# Columns: [CI_Cat, CI_Subcat, Status, Impact, Urgency, Priority, number_cnt, Category, No_of_Reassignments, Open_Time, Reopen_Time, Resolved_Time, Close_Time, Handle_Time_hrs, Closure_Code, No_of_Related_Interactions, No_of_Related_Incidents, No_of_Related_Changes]
# Index: []

# %%
len(data.loc[data["No_of_Related_Interactions"]>upper_limit])/len(data)
# Out:
# 0.07368150023602112

# %%
data.loc[data["No_of_Related_Interactions"]>upper_limit,"No_of_Related_Interactions"]=data["No_of_Related_Interactions"].median()

# %%
sns.boxplot(x=data.No_of_Related_Interactions)
# Out:
# <Axes: xlabel='No_of_Related_Interactions'>

# %% [markdown]
# * Median number of related interactions is 1.
# * 75% of tickets have 3 or fewer related interactions.
# * There are a few outliers with many related interactions (up to 20).

# %% [markdown]
# ## **Box Plot for No_of_Related_Incidents**

# %%
# Create a box plot for the 'No_of_Related_Incidents' column
plt.figure(figsize=(8,6))
sns.boxplot(x=data['No_of_Related_Incidents'])
plt.title('Box Plot of No_of_Related_Incidents')
plt.ylabel('No_of_Related_Incidents')
plt.show()

# %% [markdown]
# ## **Outliers Handle for No_of_Related_Incidents**

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=data,x='No_of_Related_Incidents',kde=True)
# Out:
# <Axes: xlabel='No_of_Related_Incidents', ylabel='Count'>

# %% [markdown]
# ## Insights
# * The most common number of related incidents is 1.
# * The distribution of the number of related incidents is skewed to the right, meaning that there are more incidents with fewer related incidents than incidents with more related incidents.
# *The maximum number of related incidents is 53.

# %%
Q1=data["No_of_Related_Incidents"].quantile(0.25)
print("lower_quartile",Q1)
Q3=data["No_of_Related_Incidents"].quantile(0.75)
print("upper_quartile",Q3)
# Out:
# lower_quartile 1.0
# upper_quartile 1.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 0.0

# %%
lower_limit=Q1-1.5*IQR
print("lower_limit is",lower_limit)
upper_limit=Q3+1.5*IQR
print("upper_limit is",upper_limit)
# Out:
# lower_limit is 1.0
# upper_limit is 1.0

# %%
data.loc[data["No_of_Related_Incidents"]>upper_limit]
# Out:
#                CI_Cat                 CI_Subcat  Status Impact Urgency  \
# 0      subapplication     Web Based Application  Closed      4       4
# 13        application     Web Based Application  Closed      4       4
# 15        application     Web Based Application  Closed      4       4
# 20        application     Web Based Application  Closed      4       4
# 119       application      Standard Application  Closed      5       5
# ...               ...                       ...     ...    ...     ...
# 45336     application  Server Based Application  Closed      3       3
# 45411     application       Desktop Application  Closed      2       3
# 45962  subapplication     Web Based Application  Closed      2       2
# 46263  subapplication     Web Based Application  Closed      5       5
# 46416     application     Web Based Application  Closed      3       1
#
#        Priority  number_cnt  Category  No_of_Reassignments         Open_Time  \
# 0           4.0    0.601292  incident                  0.0    5/2/2012 13:32
# 13          4.0    0.592713  incident                  0.0  15-10-2012 15:50
# 15          4.0    0.701705  incident                  3.0  23-10-2012 12:01
# 20          4.0    0.428148  incident                  0.0  24-12-2012 16:31
# 119         5.0    0.875886  incident                  2.0  26-06-2013 12:09
# ...         ...         ...       ...                  ...               ...
# 45336       3.0    0.496306  incident                  0.0  25-03-2014 03:30
# 45411       2.0    0.427608  incident                  1.0  25-03-2014 11:56
# 45962       2.0    0.922142  incident                  0.0  27-03-2014 08:22
# 46263       5.0    0.572573  incident                  2.0  28-03-2014 10:19
# 46416       2.0    0.870740  incident                  2.0  31-03-2014 08:00
#
#       Reopen_Time     Resolved_Time        Close_Time Handle_Time_hrs  \
# 0             NaN   4/11/2013 13:50   4/11/2013 13:51  3,87,16,91,111
# 13            NaN               NaN  14-11-2013 13:33  6,67,54,16,667
# 15            NaN   8/11/2013 14:57   8/11/2013 14:58  2,83,79,50,556
# 20            NaN  14-11-2013 09:49  14-11-2013 09:49  1,93,04,83,333
# 119           NaN  18-11-2013 09:14  18-11-2013 09:15  5,23,78,69,444
# ...           ...               ...               ...             ...
# 45336         NaN  25-03-2014 15:45  25-03-2014 15:46  2,84,83,33,333
# 45411         NaN  26-03-2014 08:10  26-03-2014 08:11  7,16,91,66,667
# 45962         NaN  27-03-2014 09:31  27-03-2014 09:33  1,19,55,55,556
# 46263         NaN  29-03-2014 08:24  29-03-2014 08:24  7,66,86,11,111
# 46416         NaN  31-03-2014 12:04  31-03-2014 12:05            4,07
#
#       Closure_Code  No_of_Related_Interactions  No_of_Related_Incidents  \
# 0            Other                         1.0                      2.0
# 13        Software                         1.0                      2.0
# 15           Other                         1.0                      2.0
# 20        Referred                         1.0                      2.0
# 119       Software                         1.0                      2.0
# ...            ...                         ...                      ...
# 45336     Hardware                         1.0                      2.0
# 45411     Software                         1.0                     15.0
# 45962        Other                         1.0                      8.0
# 46263        Other                         1.0                      2.0
# 46416     Software                         1.0                     12.0
#
#        No_of_Related_Changes
# 0                        NaN
# 13                       NaN
# 15                       NaN
# 20                       NaN
# 119                      1.0
# ...                      ...
# 45336                    NaN
# 45411                    1.0
# 45962                    NaN
# 46263                    NaN
# 46416                    1.0
#
# [165 rows x 18 columns]

# %%
len(data.loc[data["No_of_Related_Incidents"]>upper_limit])/len(data)
# Out:
# 0.003540316697420933

# %%
data.loc[data["No_of_Related_Incidents"]>upper_limit,"No_of_Related_Incidents"]=data["No_of_Related_Incidents"].median()

# %%
sns.boxplot(x=data.No_of_Related_Incidents)
# Out:
# <Axes: xlabel='No_of_Related_Incidents'>

# %% [markdown]
# ## **Box Plot for No_of_Related_Changes**

# %%
# Create a box plot for the 'No_of_Related_Changes' column
plt.figure(figsize=(8,6))
sns.boxplot(x=data['No_of_Related_Changes'])
plt.title('Box Plot of No_of_Related_Changes')
plt.ylabel('No_of_Related_Changes')
plt.show()

# %% [markdown]
# ## Outliers Handle for No_of_Related_changes

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=data,x='No_of_Related_Changes',kde=True)
# Out:
# <Axes: xlabel='No_of_Related_Changes', ylabel='Count'>

# %% [markdown]
# ### **Insights**
# * The most common number of related changes is 1.
# * The distribution of the number of related changes is skewed to the right, meaning that there are more changes with fewer related changes than changes with more related changes.
# * The maximum number of related changes is 53.
# * The median number of related changes is 2.
# * The 75th percentile of the number of related changes is 4.
# * The 95th percentile of the number of related changes is 10.

# %%
Q1=data["No_of_Related_Changes"].quantile(0.25)
print("lower_quartile",Q1)
Q3=data["No_of_Related_Changes"].quantile(0.75)
print("upper_quartile",Q3)
# Out:
# lower_quartile 1.0
# upper_quartile 1.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 0.0

# %%
lower_limit=Q1-1.5*IQR
print("lower_limit is",lower_limit)
upper_limit=Q3+1.5*IQR
print("upper_limit is",upper_limit)
# Out:
# lower_limit is 1.0
# upper_limit is 1.0

# %%
data.loc[data["No_of_Related_Changes"]>upper_limit]
# Out:
#                CI_Cat                 CI_Subcat  Status Impact Urgency  \
# 38        application     Web Based Application  Closed      3       3
# 134       application      Standard Application  Closed      4       4
# 360       application     Web Based Application  Closed      4       4
# 403    subapplication     Web Based Application  Closed     NS       3
# 578       application       Desktop Application  Closed      4       4
# 699       application     Web Based Application  Closed      5       5
# 3031      application  Server Based Application  Closed      5       5
# 4912      application     Web Based Application  Closed      5       5
# 8907      application     Web Based Application  Closed      4       4
# 19350     application  Server Based Application  Closed      4       4
# 19663     application     Web Based Application  Closed      3       3
# 22474     application  Server Based Application  Closed      5       5
# 23143     application  Server Based Application  Closed      5       5
# 24182  subapplication     Web Based Application  Closed      3       3
# 25831     application  Server Based Application  Closed      5       5
# 26001     application  Server Based Application  Closed      5       5
# 26359     application  Server Based Application  Closed      5       5
# 28487     application  Server Based Application  Closed      2       2
# 31205     application     Web Based Application  Closed      4       4
# 35446     application  Server Based Application  Closed      4       4
# 37496  subapplication     Web Based Application  Closed      2       2
# 37566     application  Server Based Application  Closed      5       5
# 39643     application     Web Based Application  Closed      5       5
# 42082     application     Web Based Application  Closed      4       4
#
#        Priority  number_cnt                 Category  No_of_Reassignments  \
# 38          3.0    0.481873                 incident                  4.0
# 134         4.0    0.877301                 incident                  2.0
# 360         4.0    0.261065                 incident                  0.0
# 403         4.0    0.709596                 incident                  0.0
# 578         4.0    0.354227                 incident                  2.0
# 699         5.0    0.574457  request for information                  0.0
# 3031        5.0    0.673485                 incident                  0.0
# 4912        5.0    0.631183                 incident                  0.0
# 8907        4.0    0.456999                 incident                  0.0
# 19350       4.0    0.205976                 incident                  2.0
# 19663       3.0    0.515405                 incident                  1.0
# 22474       5.0    0.935779                 incident                  1.0
# 23143       5.0    0.546495                 incident                  0.0
# 24182       3.0    0.870326                 incident                  4.0
# 25831       5.0    0.205965                 incident                  0.0
# 26001       5.0    0.562280                 incident                  0.0
# 26359       5.0    0.813398                 incident                  0.0
# 28487       2.0    0.878408                 incident                  0.0
# 31205       4.0    0.644956                 incident                  0.0
# 35446       4.0    0.660153                 incident                  4.0
# 37496       2.0    0.443851                 incident                  4.0
# 37566       5.0    0.537506                 incident                  0.0
# 39643       5.0    0.720412                 incident                  2.0
# 42082       4.0    0.582007                 incident                  2.0
#
#               Open_Time       Reopen_Time     Resolved_Time        Close_Time  \
# 38       5/3/2013 13:58               NaN   8/11/2013 15:35   8/11/2013 15:35
# 134      5/7/2013 13:35               NaN  18-11-2013 09:22  18-11-2013 09:24
# 360     10/9/2013 13:09               NaN   5/12/2013 10:16   5/12/2013 10:17
# 403     12/9/2013 11:14               NaN  25-03-2014 12:52  25-03-2014 12:52
# 578    23-09-2013 14:54               NaN  11/10/2013 12:41  11/10/2013 13:24
# 699    25-09-2013 11:36               NaN  22-10-2013 08:56  22-10-2013 08:56
# 3031    7/10/2013 10:57  11/10/2013 10:32  14-10-2013 09:21  14-10-2013 09:21
# 4912   14-10-2013 11:57               NaN    4/11/2013 8:44    4/11/2013 8:44
# 8907   29-10-2013 14:24               NaN   5/11/2013 13:25   5/11/2013 13:26
# 19350   6/12/2013 10:41               NaN   6/12/2013 14:05   6/12/2013 14:05
# 19663   8/12/2013 11:41               NaN  18-12-2013 08:40  18-12-2013 08:41
# 22474  18-12-2013 15:25               NaN    6/2/2014 13:45    6/2/2014 13:46
# 23143  20-12-2013 18:16               NaN    4/2/2014 12:03    4/2/2014 12:03
# 24182  30-12-2013 11:40    9/1/2014 15:31  20-01-2014 12:06  20-01-2014 12:06
# 25831    7/1/2014 12:01               NaN    8/1/2014 13:44    8/1/2014 13:49
# 26001    7/1/2014 16:46               NaN    8/1/2014 13:50    8/1/2014 13:51
# 26359    8/1/2014 15:18               NaN    4/2/2014 12:05    4/2/2014 12:05
# 28487  16-01-2014 16:57  29-01-2014 10:10  30-01-2014 08:51  30-01-2014 08:51
# 31205  27-01-2014 14:28               NaN  29-01-2014 11:29  29-01-2014 11:30
# 35446   10/2/2014 16:53               NaN  26-02-2014 08:33  26-02-2014 08:34
# 37496  18-02-2014 14:49               NaN  19-02-2014 11:50  19-02-2014 11:50
# 37566  18-02-2014 16:02               NaN  20-02-2014 12:42  20-02-2014 12:43
# 39643  27-02-2014 08:19               NaN    4/3/2014 14:13    4/3/2014 14:13
# 42082   10/3/2014 16:17               NaN  26-03-2014 16:28  26-03-2014 16:28
#
#       Handle_Time_hrs    Closure_Code  No_of_Related_Interactions  \
# 38     2,16,22,22,222        Software                         1.0
# 134            0,2175  Operator error                         1.0
# 360    6,48,13,36,111         Unknown                         1.0
# 403    7,72,98,61,111           Other                         1.0
# 578    1,05,77,97,222           Other                         1.0
# 699    1,44,97,22,222           Other                         1.0
# 3031   1,34,83,05,556        Software                         1.0
# 4912   2,48,34,72,222        Software                         1.0
# 8907   5,15,29,44,444        Software                         1.0
# 19350  3,41,30,55,556           Other                         1.0
# 19663  3,49,40,55,556  Operator error                         1.0
# 22474  2,57,41,66,667           Other                         1.0
# 23143  3,77,36,11,111        Software                         1.0
# 24182  8,21,34,44,444        Software                         1.0
# 25831  2,45,86,11,111  Operator error                         1.0
# 26001  7,59,13,88,889  Operator error                         1.0
# 26359  3,90,27,77,778        Software                         1.0
# 28487  2,93,86,47,222           Other                         1.0
# 31205  1,80,31,38,889        Software                         1.0
# 35446       11,76,675        Software                         1.0
# 37496  2,10,29,16,667        Software                         1.0
# 37566     0,883333333        Software                         1.0
# 39643  3,74,01,38,889        Software                         1.0
# 42082       10,78,325        Software                         1.0
#
#        No_of_Related_Incidents  No_of_Related_Changes
# 38                         NaN                    2.0
# 134                        1.0                    2.0
# 360                        NaN                    3.0
# 403                        1.0                    2.0
# 578                        NaN                    2.0
# 699                        NaN                    2.0
# 3031                       NaN                    2.0
# 4912                       NaN                    2.0
# 8907                       NaN                    2.0
# 19350                      NaN                    2.0
# 19663                      NaN                    2.0
# 22474                      NaN                    2.0
# 23143                      NaN                    2.0
# 24182                      1.0                    9.0
# 25831                      NaN                    2.0
# 26001                      NaN                    2.0
# 26359                      NaN                    2.0
# 28487                      1.0                    2.0
# 31205                      1.0                    2.0
# 35446                      NaN                    2.0
# 37496                      NaN                    2.0
# 37566                      NaN                    2.0
# 39643                      NaN                    2.0
# 42082                      NaN                    3.0

# %%
len(data.loc[data["No_of_Related_Changes"]>upper_limit])/len(data)
# Out:
# 0.0005149551559884993

# %%
data.loc[data["No_of_Related_Changes"]>upper_limit,"No_of_Related_Changes"]=data["No_of_Related_Changes"].median()

# %%
sns.boxplot(x=data.No_of_Related_Changes)
# Out:
# <Axes: xlabel='No_of_Related_Changes'>
